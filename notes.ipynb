# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Testing

# %%
from main import *
import json

json.loads(orbit_api({'json': {
    'source': 'dining'
}, 'args': None}))
# Out:
# {'Cafe 3': {'times': 'Times for Fri, Mar 26:\n7:30 a.m. - 10:30 a.m.\n11:00 a.m. - 4:30 p.m.\n5:00 p.m. - 8:00 p.m.',
#   'periods': [{'name': 'Breakfast',
#     'categories': [{'name': 'BREAKFAST', 'items': ['Continental Breakfast']}]},
#    {'name': 'Lunch',
#     'categories': [{'name': 'CENTER PLATE',
#       'items': ['Mustard Crusted Halal Salmon',
#        'Quinoa Pilaf',
#        'Sauteed Kale with Onions and Mushrooms',
#        'Vegan Nuggets']},
#      {'name': 'PASTAS',
#       'items': ['Mushroom Duxelle Pasta Bake',
#        'Italian Herb Vegan Strips',
#        'Sauteed Spinach',
#        'Garlic French Bread']},
#      {'name': 'ALLERGEN FRIENDLY',
#       'items': ['Wild Rice and Eggplant Bear Fit Bowl',
#        'Halal Beef',
#        'Halal Chicken']},
#      {'name': 'SOUP/SALAD',
#       'items': ['Mixed Green Salad with Balsamic Vinaigrette',
#        'Caesar Salad',
#        'Nicoise Salad',
#        'Tomato Garden Soup',
#        'Italian Wedding Soup']},
# ...
